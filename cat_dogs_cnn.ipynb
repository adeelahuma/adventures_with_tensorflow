# %% [markdown]
# ## Cats and Dogs Classification

# %%
import numpy as np
import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator

import os

import matplotlib.pyplot as plt

# %%
_URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'
zip_dir = tf.keras.utils.get_file('cats_and_dogs_filterted.zip', origin=_URL, extract=True)

# %%
zip_dir
# Out:
# '/Users/adeela/.keras/datasets/cats_and_dogs_filterted.zip'

# %%
# !unzip /Users/adeela/.keras/datasets/cats_and_dogs_filterted.zip

# %%
# !ls -l  /Users/adeela/.keras/datasets/cats_and_dogs_filtered
# Out:
# total 8
# drwxr-xr-x  5 adeela  staff  160 Aug 28 10:55 train
# drwxr-xr-x  4 adeela  staff  128 Aug 28 10:33 validation
# -rw-r--r--  1 adeela  staff  140 Aug 28 11:30 vectorize.py

# %%
zip_dir_base = os.path.dirname(zip_dir)

# %%
base_dir = os.path.join(zip_dir_base, 'cats_and_dogs_filtered')
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

train_cats_dir = os.path.join(train_dir, 'cats')
train_dogs_dir = os.path.join(train_dir, 'dogs')

validation_cats_dir = os.path.join(validation_dir, 'cats')
validation_dogs_dir = os.path.join(validation_dir, 'dogs')

# %%
num_cats_train = len(os.listdir(train_cats_dir))
num_dogs_train = len(os.listdir(train_dogs_dir))

num_cats_val = len(os.listdir(validation_cats_dir))
num_dogs_val = len(os.listdir(validation_dogs_dir))

total_train = num_cats_train + num_dogs_train
total_val = num_cats_val + num_dogs_val

# %%
print("Total Training {}".format(total_train))
print("Train cats {} ".format(num_dogs_train))
print("Train dogs {}".format(num_cats_train))
# Out:
# Total Training 2000
# Train cats 1000
# Train dogs 1000

# %%
print("Total Validation {}".format(total_val))
print("Val cats {} ".format(num_dogs_val))
print("Val dogs {}".format(num_cats_val))
# Out:
# Total Validation 1000
# Val cats 500
# Val dogs 500

# %% [markdown]
# ## Setting Model Parameters

# %%
BATCH_SIZE =10
IMG_SHAPE=150

# %% [markdown]
# ## Data Prep

# %%
train_img_generator = ImageDataGenerator(rescale=1./255)
val_img_generator = ImageDataGenerator(rescale=1./255)

# %%
train_data_gen = train_img_generator.flow_from_directory(
                                      directory=train_dir,
                                       batch_size=BATCH_SIZE, 
                                       shuffle=True, 
                                       target_size= (IMG_SHAPE, IMG_SHAPE),
                                       class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
val_data_gen = val_img_generator.flow_from_directory(
                                      directory=validation_dir,
                                       batch_size=BATCH_SIZE, 
                                       shuffle=True, 
                                       target_size= (IMG_SHAPE, IMG_SHAPE),
                                       class_mode='binary')
# Out:
# Found 1000 images belonging to 2 classes.

# %%
sample_training_images, labels = next(train_data_gen)

# %%
plt.imshow(sample_training_images[0])
plt.show()

# %%
plt.imshow(sample_training_images[3])
plt.show()

# %% [markdown]
# ## Model Creation

# %%
l0 = tf.keras.layers.Conv2D(32, (3,3), padding='same', activation=tf.nn.relu, input_shape=(150,150,3))
l1 = tf.keras.layers.MaxPool2D((2,2), strides=2)

l2 = tf.keras.layers.Conv2D(64, (3,3), padding='same', activation=tf.nn.relu)
l3 = tf.keras.layers.MaxPool2D((2,2), strides=2)

l4 = tf.keras.layers.Conv2D(128, (3,3), padding='same', activation=tf.nn.relu)
l5 = tf.keras.layers.MaxPool2D((2,2), strides=2)

l6 = tf.keras.layers.Conv2D(128, (3,3), padding='same', activation=tf.nn.relu)
l7 = tf.keras.layers.MaxPool2D((2,2), strides=2)

l8 = tf.keras.layers.Flatten()
l9 = tf.keras.layers.Dense(units=512, activation='relu')
l10 = tf.keras.layers.Dense(units=2)

# %%
model = tf.keras.Sequential([l0,l1,l2,l3,l4,l5,l6,l7,l8,l9,l10])

model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'], 
             optimizer='adam')

# %% [markdown]
# ## Model Summary

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 10368)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               5308928
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 5,550,786
# Trainable params: 5,550,786
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
EPOCHS = 100

# %%
history = model.fit_generator(train_data_gen, 
                             steps_per_epoch=int(np.ceil(total_train/BATCH_SIZE)), 
                             epochs =EPOCHS, 
                             validation_data= val_data_gen, 
                             validation_steps=int(np.ceil(total_val/BATCH_SIZE)))
# Out:
# WARNING:tensorflow:From <ipython-input-22-6bbd9ec9c60a>:1: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 200/200 [==============================] - 32s 159ms/step - loss: 0.7007 - accuracy: 0.4975 - val_loss: 0.6930 - val_accuracy: 0.5000
# Epoch 2/100
# 200/200 [==============================] - 35s 173ms/step - loss: 0.6852 - accuracy: 0.5690 - val_loss: 0.6765 - val_accuracy: 0.6060
# Epoch 3/100
# 200/200 [==============================] - 33s 164ms/step - loss: 0.6595 - accuracy: 0.6190 - val_loss: 0.7302 - val_accuracy: 0.6010
# Epoch 4/100
# 200/200 [==============================] - 35s 174ms/step - loss: 0.6317 - accuracy: 0.6725 - val_loss: 0.6300 - val_accuracy: 0.6620
# Epoch 5/100
# 200/200 [==============================] - 33s 164ms/step - loss: 0.5939 - accuracy: 0.6855 - val_loss: 0.6494 - val_accuracy: 0.6320
# Epoch 6/100
# 200/200 [==============================] - 32s 159ms/step - loss: 0.5767 - accuracy: 0.6965 - val_loss: 0.6645 - val_accuracy: 0.6270
# Epoch 7/100
# 200/200 [==============================] - 32s 158ms/step - loss: 0.5087 - accuracy: 0.7425 - val_loss: 0.7754 - val_accuracy: 0.6190
# Epoch 8/100
# 200/200 [==============================] - 32s 158ms/step - loss: 0.4492 - accuracy: 0.7915 - val_loss: 0.7183 - val_accuracy: 0.6440
# Epoch 9/100
# 200/200 [==============================] - 33s 164ms/step - loss: 0.3345 - accuracy: 0.8465 - val_loss: 0.9454 - val_accuracy: 0.6350
# Epoch 10/100
# 200/200 [==============================] - 33s 163ms/step - loss: 0.2170 - accuracy: 0.9110 - val_loss: 1.0713 - val_accuracy: 0.6730
# Epoch 11/100
# 200/200 [==============================] - 33s 163ms/step - loss: 0.1151 - accuracy: 0.9565 - val_loss: 1.4251 - val_accuracy: 0.6570
# Epoch 12/100
# 200/200 [==============================] - 33s 163ms/step - loss: 0.0602 - accuracy: 0.9780 - val_loss: 1.8529 - val_accuracy: 0.6530
# Epoch 13/100
# 200/200 [==============================] - 32s 162ms/step - loss: 0.0562 - accuracy: 0.9825 - val_loss: 1.8159 - val_accuracy: 0.6580
# Epoch 14/100
# 200/200 [==============================] - 32s 162ms/step - loss: 0.0470 - accuracy: 0.9900 - val_loss: 1.8247 - val_accuracy: 0.6860
# Epoch 15/100
# 200/200 [==============================] - 33s 167ms/step - loss: 0.0045 - accuracy: 0.9995 - val_loss: 2.1151 - val_accuracy: 0.6840
# Epoch 16/100
# 200/200 [==============================] - 33s 163ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 2.5667 - val_accuracy: 0.6820
# Epoch 17/100
# 200/200 [==============================] - 32s 162ms/step - loss: 2.5577e-04 - accuracy: 1.0000 - val_loss: 2.6889 - val_accuracy: 0.6820
# Epoch 18/100
# 200/200 [==============================] - 35s 176ms/step - loss: 1.4303e-04 - accuracy: 1.0000 - val_loss: 2.7995 - val_accuracy: 0.6830
# Epoch 19/100
# 200/200 [==============================] - 36s 180ms/step - loss: 9.5096e-05 - accuracy: 1.0000 - val_loss: 2.8936 - val_accuracy: 0.6810
# Epoch 20/100
# 200/200 [==============================] - 37s 183ms/step - loss: 6.7672e-05 - accuracy: 1.0000 - val_loss: 2.9751 - val_accuracy: 0.6800
# Epoch 21/100
# 200/200 [==============================] - 37s 186ms/step - loss: 4.9214e-05 - accuracy: 1.0000 - val_loss: 3.0477 - val_accuracy: 0.6820
# Epoch 22/100
# 200/200 [==============================] - 38s 192ms/step - loss: 2.6949e-05 - accuracy: 1.0000 - val_loss: 3.2069 - val_accuracy: 0.6820
# Epoch 23/100
# 200/200 [==============================] - 36s 182ms/step - loss: 1.1679e-05 - accuracy: 1.0000 - val_loss: 3.3826 - val_accuracy: 0.6900
# Epoch 24/100
# 200/200 [==============================] - 38s 188ms/step - loss: 5.4458e-06 - accuracy: 1.0000 - val_loss: 3.4334 - val_accuracy: 0.6890
# Epoch 25/100
# 200/200 [==============================] - 34s 171ms/step - loss: 3.1768e-06 - accuracy: 1.0000 - val_loss: 3.5708 - val_accuracy: 0.6890
# Epoch 26/100
# 200/200 [==============================] - 34s 168ms/step - loss: 2.1675e-06 - accuracy: 1.0000 - val_loss: 3.6516 - val_accuracy: 0.6850
# Epoch 27/100
# 200/200 [==============================] - 34s 172ms/step - loss: 1.6456e-06 - accuracy: 1.0000 - val_loss: 3.6544 - val_accuracy: 0.6900
# Epoch 28/100
# 200/200 [==============================] - 34s 168ms/step - loss: 1.2880e-06 - accuracy: 1.0000 - val_loss: 3.7138 - val_accuracy: 0.6850
# Epoch 29/100
# 200/200 [==============================] - 33s 167ms/step - loss: 1.0359e-06 - accuracy: 1.0000 - val_loss: 3.7574 - val_accuracy: 0.6870
# Epoch 30/100
# 200/200 [==============================] - 34s 171ms/step - loss: 8.3762e-07 - accuracy: 1.0000 - val_loss: 3.7728 - val_accuracy: 0.6800
# Epoch 31/100
# 200/200 [==============================] - 33s 167ms/step - loss: 7.1460e-07 - accuracy: 1.0000 - val_loss: 3.7944 - val_accuracy: 0.6810
# Epoch 32/100
# 200/200 [==============================] - 35s 176ms/step - loss: 5.9861e-07 - accuracy: 1.0000 - val_loss: 3.8302 - val_accuracy: 0.6810
# Epoch 33/100
# 200/200 [==============================] - 35s 175ms/step - loss: 5.1069e-07 - accuracy: 1.0000 - val_loss: 3.8343 - val_accuracy: 0.6860
# Epoch 34/100
# 200/200 [==============================] - 34s 171ms/step - loss: 4.3917e-07 - accuracy: 1.0000 - val_loss: 3.8693 - val_accuracy: 0.6790
# Epoch 35/100
# 200/200 [==============================] - 35s 174ms/step - loss: 3.7754e-07 - accuracy: 1.0000 - val_loss: 3.8738 - val_accuracy: 0.6830
# Epoch 36/100
# 200/200 [==============================] - 34s 170ms/step - loss: 3.3504e-07 - accuracy: 1.0000 - val_loss: 3.9070 - val_accuracy: 0.6810
# Epoch 37/100
# 200/200 [==============================] - 35s 173ms/step - loss: 2.9749e-07 - accuracy: 1.0000 - val_loss: 3.9155 - val_accuracy: 0.6800
# Epoch 38/100
# 200/200 [==============================] - 35s 176ms/step - loss: 2.6184e-07 - accuracy: 1.0000 - val_loss: 3.9297 - val_accuracy: 0.6800
# Epoch 39/100
# 200/200 [==============================] - 35s 174ms/step - loss: 2.3621e-07 - accuracy: 1.0000 - val_loss: 3.9467 - val_accuracy: 0.6810
# Epoch 40/100
# 200/200 [==============================] - 35s 177ms/step - loss: 2.0826e-07 - accuracy: 1.0000 - val_loss: 3.9809 - val_accuracy: 0.6820
# Epoch 41/100
# 200/200 [==============================] - 35s 174ms/step - loss: 1.8549e-07 - accuracy: 1.0000 - val_loss: 3.9941 - val_accuracy: 0.6790
# Epoch 42/100
# 200/200 [==============================] - 34s 172ms/step - loss: 1.6743e-07 - accuracy: 1.0000 - val_loss: 4.0052 - val_accuracy: 0.6790
# Epoch 43/100
# 200/200 [==============================] - 33s 163ms/step - loss: 1.4883e-07 - accuracy: 1.0000 - val_loss: 4.0313 - val_accuracy: 0.6760
# Epoch 44/100
# 200/200 [==============================] - 32s 162ms/step - loss: 1.3715e-07 - accuracy: 1.0000 - val_loss: 4.0514 - val_accuracy: 0.6820
# Epoch 45/100
# 200/200 [==============================] - 35s 176ms/step - loss: 1.2302e-07 - accuracy: 1.0000 - val_loss: 4.0568 - val_accuracy: 0.6810
# Epoch 46/100
# 200/200 [==============================] - 34s 169ms/step - loss: 1.1128e-07 - accuracy: 1.0000 - val_loss: 4.0759 - val_accuracy: 0.6830
# Epoch 47/100
# 200/200 [==============================] - 36s 180ms/step - loss: 1.0139e-07 - accuracy: 1.0000 - val_loss: 4.0943 - val_accuracy: 0.6840
# Epoch 48/100
# 200/200 [==============================] - 34s 172ms/step - loss: 9.1910e-08 - accuracy: 1.0000 - val_loss: 4.1079 - val_accuracy: 0.6830
# Epoch 49/100
# 200/200 [==============================] - 33s 163ms/step - loss: 8.4639e-08 - accuracy: 1.0000 - val_loss: 4.1234 - val_accuracy: 0.6820
# Epoch 50/100
# 200/200 [==============================] - 34s 169ms/step - loss: 7.7426e-08 - accuracy: 1.0000 - val_loss: 4.1277 - val_accuracy: 0.6830
# Epoch 51/100
# 200/200 [==============================] - 35s 177ms/step - loss: 7.0572e-08 - accuracy: 1.0000 - val_loss: 4.1414 - val_accuracy: 0.6830
# Epoch 52/100
# 200/200 [==============================] - 36s 180ms/step - loss: 6.5923e-08 - accuracy: 1.0000 - val_loss: 4.1680 - val_accuracy: 0.6870
# Epoch 53/100
# 200/200 [==============================] - 34s 172ms/step - loss: 5.9247e-08 - accuracy: 1.0000 - val_loss: 4.1653 - val_accuracy: 0.6850
# Epoch 54/100
# 200/200 [==============================] - 34s 170ms/step - loss: 5.4955e-08 - accuracy: 1.0000 - val_loss: 4.1803 - val_accuracy: 0.6840
# Epoch 55/100
# 200/200 [==============================] - 34s 169ms/step - loss: 5.0902e-08 - accuracy: 1.0000 - val_loss: 4.2032 - val_accuracy: 0.6890
# Epoch 56/100
# 200/200 [==============================] - 34s 169ms/step - loss: 4.6849e-08 - accuracy: 1.0000 - val_loss: 4.2021 - val_accuracy: 0.6860
# Epoch 57/100
# 200/200 [==============================] - 36s 180ms/step - loss: 4.3094e-08 - accuracy: 1.0000 - val_loss: 4.2218 - val_accuracy: 0.6880
# Epoch 58/100
# 200/200 [==============================] - 35s 177ms/step - loss: 4.0233e-08 - accuracy: 1.0000 - val_loss: 4.2320 - val_accuracy: 0.6900
# Epoch 59/100
# 200/200 [==============================] - 35s 175ms/step - loss: 3.6895e-08 - accuracy: 1.0000 - val_loss: 4.2411 - val_accuracy: 0.6840
# Epoch 60/100
# 200/200 [==============================] - 36s 178ms/step - loss: 3.4809e-08 - accuracy: 1.0000 - val_loss: 4.2470 - val_accuracy: 0.6870
# Epoch 61/100
# 200/200 [==============================] - 36s 178ms/step - loss: 3.1292e-08 - accuracy: 1.0000 - val_loss: 4.2575 - val_accuracy: 0.6860
# Epoch 62/100
# 200/200 [==============================] - 35s 174ms/step - loss: 2.8789e-08 - accuracy: 1.0000 - val_loss: 4.2751 - val_accuracy: 0.6870
# Epoch 63/100
# 200/200 [==============================] - 36s 179ms/step - loss: 2.6822e-08 - accuracy: 1.0000 - val_loss: 4.2815 - val_accuracy: 0.6880
# Epoch 64/100
# 200/200 [==============================] - 36s 179ms/step - loss: 2.5153e-08 - accuracy: 1.0000 - val_loss: 4.2879 - val_accuracy: 0.6890
# Epoch 65/100
# 200/200 [==============================] - 35s 174ms/step - loss: 2.2709e-08 - accuracy: 1.0000 - val_loss: 4.2996 - val_accuracy: 0.6860
# Epoch 66/100
# 200/200 [==============================] - 36s 178ms/step - loss: 2.1100e-08 - accuracy: 1.0000 - val_loss: 4.3082 - val_accuracy: 0.6860
# Epoch 67/100
# 200/200 [==============================] - 36s 179ms/step - loss: 1.8775e-08 - accuracy: 1.0000 - val_loss: 4.3250 - val_accuracy: 0.6870
# Epoch 68/100
# 200/200 [==============================] - 36s 179ms/step - loss: 1.6689e-08 - accuracy: 1.0000 - val_loss: 4.3298 - val_accuracy: 0.6870
# Epoch 69/100
# 200/200 [==============================] - 35s 177ms/step - loss: 1.5259e-08 - accuracy: 1.0000 - val_loss: 4.3364 - val_accuracy: 0.6860
# Epoch 70/100
# 200/200 [==============================] - 36s 180ms/step - loss: 1.4305e-08 - accuracy: 1.0000 - val_loss: 4.3488 - val_accuracy: 0.6860
# Epoch 71/100
# 200/200 [==============================] - 35s 176ms/step - loss: 1.3292e-08 - accuracy: 1.0000 - val_loss: 4.3695 - val_accuracy: 0.6860
# Epoch 72/100
# 200/200 [==============================] - 36s 180ms/step - loss: 1.2100e-08 - accuracy: 1.0000 - val_loss: 4.3790 - val_accuracy: 0.6870
# Epoch 73/100
# 200/200 [==============================] - 37s 184ms/step - loss: 1.1265e-08 - accuracy: 1.0000 - val_loss: 4.3958 - val_accuracy: 0.6870
# Epoch 74/100
# 200/200 [==============================] - 34s 169ms/step - loss: 1.0490e-08 - accuracy: 1.0000 - val_loss: 4.4135 - val_accuracy: 0.6870
# Epoch 75/100
# 200/200 [==============================] - 35s 175ms/step - loss: 9.4771e-09 - accuracy: 1.0000 - val_loss: 4.4301 - val_accuracy: 0.6870
# Epoch 76/100
# 200/200 [==============================] - 33s 166ms/step - loss: 8.8215e-09 - accuracy: 1.0000 - val_loss: 4.4457 - val_accuracy: 0.6880
# Epoch 77/100
# 200/200 [==============================] - 33s 166ms/step - loss: 7.5698e-09 - accuracy: 1.0000 - val_loss: 4.4703 - val_accuracy: 0.6860
# Epoch 78/100
# 200/200 [==============================] - 33s 164ms/step - loss: 7.8082e-09 - accuracy: 1.0000 - val_loss: 4.4962 - val_accuracy: 0.6880
# Epoch 79/100
# 200/200 [==============================] - 33s 163ms/step - loss: 7.3314e-09 - accuracy: 1.0000 - val_loss: 4.5112 - val_accuracy: 0.6860
# Epoch 80/100
# 200/200 [==============================] - 32s 162ms/step - loss: 7.2718e-09 - accuracy: 1.0000 - val_loss: 4.5359 - val_accuracy: 0.6880
# Epoch 81/100
# 200/200 [==============================] - 33s 164ms/step - loss: 6.5565e-09 - accuracy: 1.0000 - val_loss: 4.5685 - val_accuracy: 0.6850
# Epoch 82/100
# 200/200 [==============================] - 33s 163ms/step - loss: 6.6161e-09 - accuracy: 1.0000 - val_loss: 4.5816 - val_accuracy: 0.6870
# Epoch 83/100
# 200/200 [==============================] - 33s 167ms/step - loss: 5.8413e-09 - accuracy: 1.0000 - val_loss: 4.6083 - val_accuracy: 0.6860
# Epoch 84/100
# 200/200 [==============================] - 34s 168ms/step - loss: 5.4836e-09 - accuracy: 1.0000 - val_loss: 4.6578 - val_accuracy: 0.6870
# Epoch 85/100
# 200/200 [==============================] - 35s 173ms/step - loss: 5.3644e-09 - accuracy: 1.0000 - val_loss: 4.6877 - val_accuracy: 0.6860
# Epoch 86/100
# 200/200 [==============================] - 35s 177ms/step - loss: 5.4240e-09 - accuracy: 1.0000 - val_loss: 4.7109 - val_accuracy: 0.6860
# Epoch 87/100
# 200/200 [==============================] - 34s 169ms/step - loss: 5.0664e-09 - accuracy: 1.0000 - val_loss: 4.7419 - val_accuracy: 0.6850
# Epoch 88/100
# 200/200 [==============================] - 34s 169ms/step - loss: 4.7684e-09 - accuracy: 1.0000 - val_loss: 4.7885 - val_accuracy: 0.6840
# Epoch 89/100
# 200/200 [==============================] - 33s 164ms/step - loss: 4.9472e-09 - accuracy: 1.0000 - val_loss: 4.8175 - val_accuracy: 0.6870
# Epoch 90/100
# 200/200 [==============================] - 33s 164ms/step - loss: 4.7684e-09 - accuracy: 1.0000 - val_loss: 4.8589 - val_accuracy: 0.6850
# Epoch 91/100
# 200/200 [==============================] - 33s 164ms/step - loss: 4.5896e-09 - accuracy: 1.0000 - val_loss: 4.9181 - val_accuracy: 0.6880
# Epoch 92/100
# 200/200 [==============================] - 33s 166ms/step - loss: 5.1260e-09 - accuracy: 1.0000 - val_loss: 4.9636 - val_accuracy: 0.6880
# Epoch 93/100
# 200/200 [==============================] - 34s 170ms/step - loss: 4.8280e-09 - accuracy: 1.0000 - val_loss: 5.0152 - val_accuracy: 0.6880
# Epoch 94/100
# 200/200 [==============================] - 34s 169ms/step - loss: 5.0664e-09 - accuracy: 1.0000 - val_loss: 5.0519 - val_accuracy: 0.6900
# Epoch 95/100
# 200/200 [==============================] - 34s 168ms/step - loss: 4.1723e-09 - accuracy: 1.0000 - val_loss: 5.1542 - val_accuracy: 0.6870
# Epoch 96/100
# 200/200 [==============================] - 34s 170ms/step - loss: 6.7949e-09 - accuracy: 1.0000 - val_loss: 5.1337 - val_accuracy: 0.6910
# Epoch 97/100
# 200/200 [==============================] - 34s 169ms/step - loss: 4.1723e-09 - accuracy: 1.0000 - val_loss: 5.2625 - val_accuracy: 0.6880
# Epoch 98/100
# 200/200 [==============================] - 33s 166ms/step - loss: 0.4034 - accuracy: 0.9020 - val_loss: 0.7579 - val_accuracy: 0.4930
# Epoch 99/100
# 200/200 [==============================] - 33s 165ms/step - loss: 0.7003 - accuracy: 0.5175 - val_loss: 0.7071 - val_accuracy: 0.5050
# Epoch 100/100
# 200/200 [==============================] - 34s 170ms/step - loss: 0.6938 - accuracy: 0.5235 - val_loss: 0.6913 - val_accuracy: 0.5310

# %% [markdown]
# ## Visualize

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range= range(EPOCHS)

# %%
plt.plot(epochs_range, acc, label = "Training Accuracy")
plt.plot(epochs_range, val_acc, label="Validation Accuracy")


plt.plot(epochs_range, loss, label="Training Loss")
plt.plot(epochs_range, val_loss, label = "Validation Loss")

plt.legend()
plt.show()
